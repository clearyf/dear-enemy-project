# %% [markdown]
# The `verbose` flag is specified here, if enabled more information is printed showing what is being changed, etc.

# %%
verbose = True

# %% [markdown]
# Import all required libraries here.

# %%
from collections import namedtuple
import re

# %% [markdown]
# First thing, import all the data from the `.boris` file, and print out how many observations are in the file, as a sanity check that all is as expected with the input data.

# %%
all_occurrance = 'all occurrence observations.boris'

import json
with open(all_occurrance, 'r') as f:
    data = json.load(f)
    original_observations = data['observations']
    num_events = 0
    for _,v in original_observations.items():
        num_events = num_events + len(v['events'])
    print(f'Have {len(original_observations)} observations with {num_events} events in total')
# Out:
# Have 79 observations with 11188 events in total

# %% [markdown]
# Create a class to represent the events.

# %%
class Event:
    __slots__ = 'timestamp', 'subject', 'type', 'recipient'

    def __init__(self, src):
        self.timestamp = src[0]
        self.subject = src[1]
        self.type = src[2]
        self.recipient = src[3]
        
        # mwr without a recipient is always with the partner
        if self.type == 'mwr' and not self.recipient:
            self.recipient = 'partner'
                
        assert self.timestamp >= 0, self
        # TODO allow empty subject for the moment
        assert any(self.subject == x for x in ['male_A', 'female_A', 'male_B', 'female_B', '']) or self.type == 'vstart', self
        assert any(self.type == x for x in ['app', 'cavity', 'fspr', 'vstart', 'bars', 'hd', 'sbend', 'freeze', 'ST', 'sb', 'pre-agg']), self
        # TODO allow empty recipient
        assert any(self.recipient == x for x in ['neighbour', 'partner', 'focal', '']), self
        
    def __format__(self, format_spec):
        return f'"{self.timestamp}, {self.subject}, {self.type}, {self.recipient}"'           

    def __str__(self):
        return f'"{self.timestamp}, {self.subject}, {self.type}, {self.recipient}"'
    
    def __repr__(self):
        return f'"{self.timestamp}, {self.subject}, {self.type}, {self.recipient}"'

# %% [markdown]
# The labels on the observations must be fixed up. "Neighbour" to "Experiment Control" and "Stranger" to "Experiment Treatment", and so on.  All labels are checked against the `pattern` regular expression that is specified here.

# %%
pattern = re.compile(
    '(F[0-9]) +([0-9]{2})\.([0-9]{2})\.? +(experiment|habituation) (treatment|control)')

def get_label(s):
    groups = re.fullmatch(pattern, s).groups()
    return f'{groups[0]} 2017.{groups[2]}.{groups[1]} {groups[3]} {groups[4]}'

def correct_label(s):
    new_k = str(s)
    new_k = new_k.replace('neighbour', 'experiment control')
    new_k = new_k.replace('stranger', 'experiment treatment')
    new_k = new_k.replace('habituation experiment', 'habituation treatment')
    new_k = new_k.replace('treatment control', 'experiment control')
    new_k = new_k.replace('habitiution control', 'habituation control')
    new_k = new_k.replace('habitiution experiment', 'habituation treatment')
    new_k = new_k.replace('habitation experiment', 'habituation treatment')
    new_k = new_k.replace('habitiution control', 'habituation control')

    # ensure that all keys now match the expected layout
    if not pattern.fullmatch(new_k):
        raise ValueError()

    new_k = get_label(new_k)    
    if new_k != s:
        if verbose:
            print(f'Change {k:>40} -> {new_k}')
    
    return new_k

# %% [markdown]
# Start by removing some events that are wrong/invalid.  If the vstart is missing at the start of the list of events then add it.  The events themselves are also touched up, the 'mwr' events are generally missing the recipient, and the timestamps are also normalised here such that vstart always happens at $t = 0$.  This makes the analysis further down easier.

# %%
observations = dict()

for k,v in original_observations.items():
    try:
        label = correct_label(k)

        events = list()
        for event in v['events']:
            if event[3] == '':
                event[3] = 'neighbour'
            event[1] = event[1].replace(' ', '_')
            if event[1].startswith('pair_'):
                print(f'Found pair event: {event}')
                (_, _, pairid) = event[1].partition('_')
                event[1] = 'male_' + pairid
                print(f'Adding event: {event}')
                events.append(Event(event))
                event[1] = 'female_' + pairid
                print(f'Adding event: {event}')
                events.append(Event(event))
            else:
                print(f'Adding event: {event}')
                events.append(Event(event))
        
        if not events:
            print(f'Observation {label} has no events!')
            continue

        if events[0].type != 'vstart':
            if verbose:
                print(f'Observation {label} is missing a vstart as the very first event!')
            # for the moment add a vstart with t = 0
            events.insert(0, Event([0.0, "", "vstart", "", ""]))
    
        vstart_timestamp = events[0].timestamp
        for event in events:
            # normalise timestamps so that the vstart timestamp is always 0
            event.timestamp = event.timestamp - vstart_timestamp

        observations[label] = events

    except ValueError as e:
        if k.startswith('x'):
            print(f'Observation {k!r} is marked as invalid (starts with "x")')
        else:
            print(f'Observation {k!r} is invalid: {e}')
# Out:
# Change            F5 09.06. habituation control -> F5 2017.06.09 habituation control
# Adding event: [0.0, '', 'vstart', 'neighbour', '']
# Adding event: [38.312, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [44.545, 'male_A', 'app', 'partner', '']
# Adding event: [66.898, 'female_B', 'fspr', 'partner', '']
# Adding event: [78.352, 'female_A', 'app', 'neighbour', '']
# Adding event: [84.266, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [90.3, 'male_B', 'fspr', 'partner', '']
# Adding event: [101.65, 'female_B', 'ST', 'neighbour', '']
# Adding event: [111.17, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [117.405, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [122.214, 'female_B', 'ST', 'neighbour', '']
# Adding event: [137.582, 'male_B', 'ST', 'neighbour', '']
# Adding event: [144.153, 'female_B', 'ST', 'neighbour', '']
# Adding event: [151.024, 'female_B', 'ST', 'neighbour', '']
# Adding event: [154.606, 'female_B', 'ST', 'neighbour', '']
# Adding event: [161.524, 'female_B', 'ST', 'neighbour', '']
# Adding event: [168.152, 'female_B', 'ST', 'neighbour', '']
# Adding event: [175.999, 'female_B', 'ST', 'neighbour', '']
# Found pair event: [178.731, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [178.731, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [178.731, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [180.439, 'female_B', 'ST', 'neighbour', '']
# Adding event: [186.328, 'female_B', 'ST', 'neighbour', '']
# Adding event: [190.915, 'male_B', 'ST', 'neighbour', '']
# Adding event: [193.965, 'female_B', 'ST', 'neighbour', '']
# Adding event: [200.344, 'male_B', 'ST', 'neighbour', '']
# Adding event: [203.17, 'female_B', 'ST', 'neighbour', '']
# Adding event: [205.719, 'female_B', 'ST', 'neighbour', '']
# Adding event: [209.047, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [216.938, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [241.367, 'female_B', 'ST', 'neighbour', '']
# Adding event: [244.908, 'female_B', 'ST', 'neighbour', '']
# Adding event: [252.738, 'male_B', 'fspr', 'partner', '']
# Adding event: [261.356, 'female_B', 'ST', 'neighbour', '']
# Adding event: [264.407, 'male_B', 'ST', 'neighbour', '']
# Adding event: [267.574, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [271.742, 'male_B', 'ST', 'neighbour', '']
# Adding event: [274.901, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [276.393, 'male_B', 'ST', 'neighbour', '']
# Adding event: [290.213, 'female_B', 'ST', 'neighbour', '']
# Adding event: [294.576, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [298.505, 'male_A', 'fspr', 'partner', '']
# Adding event: [300.38, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [311.424, 'male_B', 'ST', 'neighbour', '']
# Adding event: [318.016, 'female_B', 'ST', 'neighbour', '']
# Adding event: [322.268, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [328.896, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [331.695, 'female_B', 'ST', 'neighbour', '']
# Adding event: [342.441, 'female_B', 'ST', 'neighbour', '']
# Adding event: [350.04, 'female_B', 'ST', 'neighbour', '']
# Found pair event: [360.16, 'pair_B', 'fspr', 'neighbour', '']
# Adding event: [360.16, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [360.16, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [361.277, 'female_A', 'app', 'neighbour', '']
# Adding event: [362.376, 'male_A', 'app', 'neighbour', '']
# Adding event: [364.72, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [370.847, 'male_B', 'ST', 'neighbour', '']
# Adding event: [380.411, 'male_B', 'ST', 'neighbour', '']
# Adding event: [385.215, 'female_B', 'ST', 'neighbour', '']
# Adding event: [389.617, 'female_B', 'ST', 'neighbour', '']
# Adding event: [395.241, 'male_B', 'ST', 'neighbour', '']
# Adding event: [399.289, 'female_B', 'ST', 'neighbour', '']
# Adding event: [406.378, 'male_B', 'ST', 'neighbour', '']
# Adding event: [410.431, 'female_B', 'ST', 'neighbour', '']
# Adding event: [417.558, 'female_B', 'ST', 'neighbour', '']
# Adding event: [420.21, 'female_A', 'app', 'neighbour', '']
# Adding event: [424.847, 'female_B', 'ST', 'neighbour', '']
# Adding event: [433.564, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [441.385, 'female_B', 'ST', 'neighbour', '']
# Adding event: [443.871, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [444.123, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [444.558, 'female_A', 'app', 'neighbour', '']
# Adding event: [445.561, 'female_A', 'app', 'neighbour', '']
# Adding event: [446.391, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [446.391, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [447.379, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [449.682, 'female_A', 'app', 'neighbour', '']
# Adding event: [456.814, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [456.814, 'male_B', 'ST', 'neighbour', '']
# Adding event: [463.44, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [467.428, 'male_B', 'ST', 'neighbour', '']
# Adding event: [471.356, 'male_A', 'ST', 'neighbour', '']
# Adding event: [476.14, 'female_B', 'ST', 'neighbour', '']
# Adding event: [476.913, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [481.999, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [482.862, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [489.029, 'female_B', 'ST', 'neighbour', '']
# Adding event: [492.339, 'male_A', 'ST', 'neighbour', '']
# Adding event: [493.675, 'male_B', 'ST', 'neighbour', '']
# Adding event: [494.177, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [498.08, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [502.445, 'male_A', 'ST', 'neighbour', '']
# Adding event: [509.474, 'female_B', 'ST', 'neighbour', '']
# Adding event: [512.274, 'male_B', 'ST', 'neighbour', '']
# Adding event: [514.792, 'male_A', 'ST', 'neighbour', '']
# Adding event: [517.331, 'female_B', 'ST', 'neighbour', '']
# Adding event: [520.36, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [522.13, 'male_B', 'ST', 'neighbour', '']
# Adding event: [524.882, 'female_B', 'ST', 'neighbour', '']
# Adding event: [532.041, 'female_B', 'ST', 'neighbour', '']
# Adding event: [543.762, 'male_B', 'ST', 'neighbour', '']
# Found pair event: [546.502, 'pair_B', 'fspr', 'neighbour', '']
# Adding event: [546.502, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [546.502, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [551.146, 'male_A', 'app', 'partner', '']
# Adding event: [553.701, 'male_B', 'ST', 'neighbour', '']
# Adding event: [554.0, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [566.859, 'male_B', 'ST', 'neighbour', '']
# Adding event: [575.271, 'male_B', 'ST', 'neighbour', '']
# Adding event: [576.029, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [582.368, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [590.396, 'male_B', 'ST', 'neighbour', '']
# Adding event: [598.059, 'female_B', 'ST', 'neighbour', '']
# Adding event: [599.098, 'female_B', 'cavity', 'neighbour', '']
# Change          F6 15.07. habituation treatment -> F6 2017.07.15 habituation treatment
# Adding event: [0.013, '', 'vstart', 'neighbour', '']
# Adding event: [4.427, 'female_B', 'app', 'partner', '']
# Adding event: [22.123, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [24.16, 'female_A', 'ST', 'neighbour', '']
# Adding event: [32.837, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [35.769, 'male_B', 'fspr', 'partner', '']
# Adding event: [38.477, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [42.815, 'male_A', 'ST', 'neighbour', '']
# Adding event: [46.011, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [46.011, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [50.113, 'female_A', 'ST', 'neighbour', '']
# Adding event: [53.605, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [67.817, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [69.084, 'female_A', 'ST', 'neighbour', '']
# Adding event: [76.732, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [77.76, 'female_A', 'ST', 'neighbour', '']
# Adding event: [80.393, 'female_A', 'app', 'partner', '']
# Adding event: [80.393, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [92.244, 'female_A', 'ST', 'neighbour', '']
# Adding event: [112.169, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [120.344, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [120.874, 'female_A', 'ST', 'neighbour', '']
# Adding event: [136.279, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [136.279, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [138.761, 'female_A', 'ST', 'neighbour', '']
# Adding event: [141.676, 'male_B', 'fspr', 'partner', '']
# Adding event: [153.674, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [159.253, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [161.855, 'female_A', 'ST', 'neighbour', '']
# Adding event: [163.39, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [168.999, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [170.265, 'female_A', 'ST', 'neighbour', '']
# Adding event: [178.709, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [179.714, 'female_A', 'ST', 'neighbour', '']
# Adding event: [191.082, 'male_B', 'app', 'neighbour', '']
# Adding event: [191.889, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [191.889, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [191.889, 'male_B', 'app', 'neighbour', '']
# Adding event: [194.449, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [194.825, 'male_B', 'app', 'neighbour', '']
# Adding event: [195.56, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [196.417, 'male_B', 'app', 'neighbour', '']
# Adding event: [199.231, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [209.04, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [210.845, 'female_A', 'ST', 'neighbour', '']
# Adding event: [220.106, 'female_A', 'ST', 'neighbour', '']
# Adding event: [222.265, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [228.117, 'male_A', 'hd', 'neighbour', '']
# Adding event: [229.713, 'female_A', 'hd', 'neighbour', '']
# Adding event: [231.73, 'male_B', 'fspr', 'partner', '']
# Adding event: [237.921, 'female_A', 'ST', 'neighbour', '']
# Adding event: [239.899, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [243.229, 'male_B', 'app', 'neighbour', '']
# Adding event: [244.206, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [246.587, 'female_A', 'ST', 'neighbour', '']
# Adding event: [252.462, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [255.029, 'female_A', 'ST', 'neighbour', '']
# Adding event: [262.191, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [263.939, 'female_A', 'ST', 'neighbour', '']
# Adding event: [273.917, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [274.919, 'female_A', 'ST', 'neighbour', '']
# Adding event: [282.718, 'male_B', 'app', 'neighbour', '']
# Adding event: [286.03, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [297.334, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [299.667, 'female_A', 'app', 'partner', '']
# Adding event: [305.078, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [307.155, 'female_A', 'ST', 'neighbour', '']
# Adding event: [310.477, 'male_B', 'app', 'neighbour', '']
# Adding event: [318.499, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [320.472, 'female_A', 'ST', 'neighbour', '']
# Adding event: [326.469, 'female_B', 'app', 'partner', '']
# Adding event: [329.114, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [331.684, 'female_A', 'ST', 'neighbour', '']
# Adding event: [334.809, 'female_A', 'ST', 'neighbour', '']
# Adding event: [338.918, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [339.885, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [345.079, 'female_A', 'ST', 'neighbour', '']
# Adding event: [345.735, 'male_B', 'app', 'neighbour', '']
# Adding event: [353.375, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [354.909, 'female_A', 'ST', 'neighbour', '']
# Adding event: [362.082, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [364.119, 'female_A', 'ST', 'neighbour', '']
# Adding event: [367.957, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [370.234, 'female_A', 'ST', 'neighbour', '']
# Adding event: [373.689, 'male_B', 'ST', 'neighbour', '']
# Adding event: [382.609, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [390.549, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [395.88, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [397.347, 'female_B', 'app', 'partner', '']
# Adding event: [397.347, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [404.365, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [407.199, 'female_A', 'ST', 'neighbour', '']
# Adding event: [411.274, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [413.199, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [415.01, 'female_A', 'ST', 'neighbour', '']
# Adding event: [418.345, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [420.62, 'female_A', 'ST', 'neighbour', '']
# Adding event: [423.954, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [425.729, 'female_A', 'ST', 'neighbour', '']
# Adding event: [436.108, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [444.51, 'male_B', 'ST', 'neighbour', '']
# Adding event: [447.579, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [449.854, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [457.262, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [458.56, 'female_A', 'ST', 'neighbour', '']
# Adding event: [461.364, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [463.399, 'female_A', 'ST', 'neighbour', '']
# Adding event: [466.902, 'female_A', 'fspr', 'partner', '']
# Adding event: [476.305, 'female_A', 'fspr', 'partner', '']
# Adding event: [477.382, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [479.825, 'female_A', 'ST', 'neighbour', '']
# Adding event: [484.153, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [487.115, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [487.115, 'male_A', 'ST', 'neighbour', '']
# Adding event: [490.456, 'female_A', 'ST', 'neighbour', '']
# Adding event: [492.926, 'female_B', 'ST', 'neighbour', '']
# Adding event: [492.926, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [496.418, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [499.799, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [501.192, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [505.048, 'male_A', 'ST', 'neighbour', '']
# Adding event: [505.826, 'female_A', 'ST', 'neighbour', '']
# Adding event: [509.01, 'male_B', 'ST', 'neighbour', '']
# Adding event: [515.518, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [518.695, 'female_A', 'ST', 'neighbour', '']
# Adding event: [521.691, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [523.614, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [525.039, 'female_B', 'ST', 'neighbour', '']
# Adding event: [526.425, 'female_A', 'ST', 'neighbour', '']
# Adding event: [530.688, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [534.411, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [535.858, 'male_B', 'ST', 'neighbour', '']
# Adding event: [537.814, 'female_A', 'ST', 'neighbour', '']
# Adding event: [537.814, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [538.873, 'female_B', 'ST', 'neighbour', '']
# Adding event: [543.29, 'male_A', 'ST', 'neighbour', '']
# Adding event: [544.824, 'male_B', 'ST', 'neighbour', '']
# Adding event: [546.334, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [549.664, 'female_A', 'ST', 'neighbour', '']
# Adding event: [552.23, 'male_A', 'ST', 'neighbour', '']
# Adding event: [553.128, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [555.335, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [558.109, 'female_A', 'ST', 'neighbour', '']
# Adding event: [560.172, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [563.745, 'female_B', 'ST', 'neighbour', '']
# Adding event: [565.014, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [568.084, 'female_A', 'ST', 'neighbour', '']
# Adding event: [569.089, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [570.622, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [572.577, 'female_A', 'fspr', 'partner', '']
# Adding event: [573.24, 'female_B', 'ST', 'neighbour', '']
# Adding event: [574.886, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [574.886, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [577.66, 'male_B', 'ST', 'neighbour', '']
# Adding event: [583.638, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [590.244, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [592.814, 'male_A', 'ST', 'neighbour', '']
# Change            F5 14.04. habituation control -> F5 2017.04.14 habituation control
# Adding event: [3.655, '', 'vstart', 'neighbour', '']
# Adding event: [5.588, 'female_B', 'ST', 'neighbour', '']
# Adding event: [7.596, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [10.105, 'female_B', 'ST', 'neighbour', '']
# Adding event: [12.787, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [17.909, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [20.002, 'female_B', 'ST', 'neighbour', '']
# Adding event: [24.867, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [26.919, 'female_B', 'ST', 'neighbour', '']
# Adding event: [30.493, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [32.812, 'female_B', 'ST', 'neighbour', '']
# Adding event: [36.385, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [40.258, 'female_B', 'ST', 'neighbour', '']
# Adding event: [52.387, 'female_B', 'fspr', 'neighbour', '']
# Found pair event: [55.31, 'pair_B', 'app', 'neighbour', '']
# Adding event: [55.31, 'male_B', 'app', 'neighbour', '']
# Adding event: [55.31, 'female_B', 'app', 'neighbour', '']
# Found pair event: [56.401, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [56.401, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [56.401, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [59.105, 'male_B', 'hd', 'neighbour', '']
# Adding event: [60.172, 'female_B', 'app', 'neighbour', '']
# Adding event: [63.851, 'male_B', 'app', 'neighbour', '']
# Adding event: [65.172, 'male_B', 'app', 'neighbour', '']
# Adding event: [69.952, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [73.558, 'male_B', 'app', 'neighbour', '']
# Adding event: [79.311, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [82.15, 'female_B', 'ST', 'neighbour', '']
# Adding event: [84.63, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [87.113, 'female_B', 'ST', 'neighbour', '']
# Adding event: [89.342, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [91.16, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [94.797, 'female_B', 'ST', 'neighbour', '']
# Adding event: [103.661, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [105.154, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [105.154, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [107.447, 'female_B', 'ST', 'neighbour', '']
# Adding event: [110.789, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [113.566, 'female_A', 'ST', 'neighbour', '']
# Adding event: [113.566, 'female_B', 'ST', 'neighbour', '']
# Adding event: [115.087, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [117.215, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [119.298, 'male_B', 'ST', 'neighbour', '']
# Adding event: [121.952, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [122.667, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [125.554, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [125.554, 'female_B', 'ST', 'neighbour', '']
# Adding event: [127.165, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [127.75, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [130.65, 'male_B', 'ST', 'neighbour', '']
# Adding event: [132.883, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [134.608, 'female_B', 'ST', 'neighbour', '']
# Adding event: [134.608, 'male_B', 'app', 'neighbour', '']
# Adding event: [140.835, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [152.255, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [156.528, 'female_B', 'ST', 'neighbour', '']
# Adding event: [158.32, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [160.605, 'female_B', 'ST', 'neighbour', '']
# Adding event: [164.208, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [166.496, 'female_B', 'ST', 'neighbour', '']
# Adding event: [178.543, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [181.594, 'female_B', 'ST', 'neighbour', '']
# Adding event: [183.408, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [186.222, 'female_B', 'ST', 'neighbour', '']
# Adding event: [191.087, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [194.398, 'female_B', 'ST', 'neighbour', '']
# Adding event: [197.102, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [198.659, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [200.195, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [202.407, 'female_A', 'ST', 'neighbour', '']
# Adding event: [203.396, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [207.397, 'male_B', 'ST', 'neighbour', '']
# Adding event: [208.496, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [211.141, 'female_B', 'ST', 'neighbour', '']
# Adding event: [214.644, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [215.785, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [217.091, 'female_A', 'app', 'partner', '']
# Adding event: [222.857, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [225.544, 'female_B', 'ST', 'neighbour', '']
# Adding event: [229.146, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [231.435, 'male_B', 'ST', 'neighbour', '']
# Adding event: [248.845, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [250.394, 'female_B', 'ST', 'neighbour', '']
# Adding event: [251.657, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [255.002, 'female_B', 'ST', 'neighbour', '']
# Adding event: [258.311, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [260.891, 'male_B', 'ST', 'neighbour', '']
# Adding event: [264.467, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [267.545, 'female_B', 'ST', 'neighbour', '']
# Adding event: [277.663, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [281.084, 'female_B', 'ST', 'neighbour', '']
# Adding event: [281.841, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [282.771, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [283.648, 'female_A', 'ST', 'neighbour', '']
# Adding event: [286.445, 'male_B', 'ST', 'neighbour', '']
# Adding event: [290.544, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [293.097, 'female_B', 'ST', 'neighbour', '']
# Adding event: [293.976, 'male_B', 'app', 'neighbour', '']
# Adding event: [295.774, 'male_B', 'app', 'neighbour', '']
# Adding event: [299.312, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [300.373, 'male_A', 'fspr', 'partner', '']
# Adding event: [301.606, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [301.606, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [305.973, 'female_B', 'ST', 'neighbour', '']
# Adding event: [307.149, 'female_A', 'ST', 'neighbour', '']
# Adding event: [307.149, 'male_B', 'app', 'neighbour', '']
# Adding event: [308.249, 'male_B', 'app', 'neighbour', '']
# Adding event: [308.847, 'male_B', 'app', 'neighbour', '']
# Adding event: [313.707, 'male_B', 'app', 'neighbour', '']
# Adding event: [315.066, 'male_B', 'app', 'neighbour', '']
# Adding event: [317.629, 'male_B', 'app', 'neighbour', '']
# Found pair event: [317.629, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [317.629, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [317.629, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [319.045, 'female_B', 'app', 'neighbour', '']
# Adding event: [320.664, 'male_A', 'app', 'neighbour', '']
# Found pair event: [321.348, 'pair_B', 'app', 'neighbour', '']
# Adding event: [321.348, 'male_B', 'app', 'neighbour', '']
# Adding event: [321.348, 'female_B', 'app', 'neighbour', '']
# Found pair event: [322.354, 'pair_B', 'app', 'neighbour', '']
# Adding event: [322.354, 'male_B', 'app', 'neighbour', '']
# Adding event: [322.354, 'female_B', 'app', 'neighbour', '']
# Adding event: [323.405, 'female_B', 'app', 'neighbour', '']
# Adding event: [325.294, 'female_B', 'app', 'neighbour', '']
# Adding event: [326.013, 'male_A', 'app', 'neighbour', '']
# Adding event: [326.893, 'female_B', 'app', 'neighbour', '']
# Adding event: [326.893, 'male_B', 'fspr', 'neighbour', '']
# Found pair event: [328.094, 'pair_B', 'app', 'neighbour', '']
# Adding event: [328.094, 'male_B', 'app', 'neighbour', '']
# Adding event: [328.094, 'female_B', 'app', 'neighbour', '']
# Adding event: [328.917, 'male_B', 'app', 'neighbour', '']
# Adding event: [329.831, 'male_B', 'app', 'neighbour', '']
# Adding event: [330.623, 'male_A', 'app', 'neighbour', '']
# Adding event: [331.523, 'male_A', 'app', 'neighbour', '']
# Adding event: [332.001, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [332.001, 'male_B', 'hd', 'neighbour', '']
# Adding event: [333.331, 'female_B', 'app', 'neighbour', '']
# Adding event: [333.331, 'male_A', 'app', 'neighbour', '']
# Adding event: [334.256, 'female_B', 'app', 'neighbour', '']
# Adding event: [336.245, 'male_A', 'app', 'neighbour', '']
# Adding event: [336.707, 'male_B', 'app', 'neighbour', '']
# Adding event: [338.197, 'male_B', 'app', 'neighbour', '']
# Adding event: [352.177, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [352.745, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [361.245, 'female_A', 'ST', 'neighbour', '']
# Adding event: [374.878, 'female_A', 'ST', 'neighbour', '']
# Adding event: [375.382, 'male_B', 'app', 'neighbour', '']
# Adding event: [376.924, 'male_B', 'app', 'neighbour', '']
# Adding event: [385.528, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [389.58, 'male_B', 'ST', 'neighbour', '']
# Adding event: [395.96, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [399.838, 'female_B', 'ST', 'neighbour', '']
# Adding event: [400.722, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [403.797, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [407.152, 'female_B', 'ST', 'neighbour', '']
# Adding event: [410.243, 'male_B', 'app', 'neighbour', '']
# Adding event: [411.286, 'male_B', 'app', 'neighbour', '']
# Adding event: [411.987, 'male_B', 'app', 'neighbour', '']
# Adding event: [412.833, 'male_B', 'app', 'neighbour', '']
# Adding event: [419.016, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [420.356, 'male_A', 'ST', 'neighbour', '']
# Adding event: [421.538, 'male_B', 'ST', 'neighbour', '']
# Adding event: [424.562, 'male_A', 'fspr', 'partner', '']
# Adding event: [426.752, 'male_A', 'ST', 'neighbour', '']
# Adding event: [428.981, 'male_B', 'ST', 'neighbour', '']
# Adding event: [430.609, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [430.609, 'male_A', 'app', 'partner', '']
# Adding event: [437.742, 'female_A', 'ST', 'neighbour', '']
# Adding event: [437.742, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [441.677, 'male_B', 'ST', 'neighbour', '']
# Adding event: [449.093, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [451.407, 'female_B', 'ST', 'neighbour', '']
# Adding event: [456.274, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [459.61, 'female_B', 'ST', 'neighbour', '']
# Adding event: [460.838, 'male_B', 'app', 'neighbour', '']
# Adding event: [462.058, 'male_A', 'ST', 'neighbour', '']
# Adding event: [473.019, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [475.702, 'male_B', 'ST', 'neighbour', '']
# Adding event: [483.568, 'female_A', 'ST', 'neighbour', '']
# Adding event: [520.079, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [523.585, 'female_A', 'ST', 'neighbour', '']
# Adding event: [527.819, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [531.078, 'female_B', 'ST', 'neighbour', '']
# Adding event: [536.206, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [538.522, 'female_B', 'ST', 'neighbour', '']
# Adding event: [540.806, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [543.386, 'female_B', 'ST', 'neighbour', '']
# Adding event: [547.461, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [550.042, 'male_B', 'ST', 'neighbour', '']
# Adding event: [554.963, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [558.084, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [559.871, 'female_B', 'ST', 'neighbour', '']
# Adding event: [565.497, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [572.912, 'male_B', 'ST', 'neighbour', '']
# Adding event: [582.908, 'female_B', 'ST', 'neighbour', '']
# Adding event: [584.959, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [587.508, 'male_B', 'ST', 'neighbour', '']
# Adding event: [594.69, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [598.002, 'female_B', 'ST', 'neighbour', '']
# Change            F5 28.04. habituation control -> F5 2017.04.28 habituation control
# Adding event: [0.56, '', 'vstart', 'neighbour', '']
# Adding event: [3.661, 'male_B', 'bars', 'neighbour', '']
# Adding event: [4.215, 'female_B', 'app', 'neighbour', '']
# Adding event: [11.181, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [28.277, 'male_B', 'app', 'neighbour', '']
# Adding event: [30.795, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [36.525, 'male_B', 'app', 'neighbour', '']
# Adding event: [42.089, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [49.471, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [125.952, 'male_B', 'app', 'neighbour', '']
# Adding event: [145.786, 'male_B', 'app', 'neighbour', '']
# Adding event: [147.573, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [180.671, 'male_B', 'fspr', 'partner', '']
# Adding event: [186.651, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [187.388, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [192.786, 'male_B', 'app', 'neighbour', '']
# Adding event: [207.471, 'male_B', 'app', 'neighbour', '']
# Adding event: [209.136, 'male_B', 'app', 'neighbour', '']
# Adding event: [210.521, 'male_B', 'app', 'neighbour', '']
# Adding event: [221.082, 'male_B', 'app', 'neighbour', '']
# Adding event: [228.453, 'female_B', 'app', 'neighbour', '']
# Adding event: [229.508, 'female_B', 'app', 'neighbour', '']
# Adding event: [231.868, 'male_B', 'app', 'neighbour', '']
# Adding event: [235.374, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [238.39, 'male_B', 'app', 'neighbour', '']
# Found pair event: [240.115, 'pair_B', 'app', 'neighbour', '']
# Adding event: [240.115, 'male_B', 'app', 'neighbour', '']
# Adding event: [240.115, 'female_B', 'app', 'neighbour', '']
# Adding event: [242.033, 'male_B', 'app', 'neighbour', '']
# Adding event: [244.482, 'male_B', 'app', 'neighbour', '']
# Found pair event: [246.335, 'pair_B', 'app', 'neighbour', '']
# Adding event: [246.335, 'male_B', 'app', 'neighbour', '']
# Adding event: [246.335, 'female_B', 'app', 'neighbour', '']
# Found pair event: [247.962, 'pair_B', 'app', 'neighbour', '']
# Adding event: [247.962, 'male_B', 'app', 'neighbour', '']
# Adding event: [247.962, 'female_B', 'app', 'neighbour', '']
# Found pair event: [248.594, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [248.594, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [248.594, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [249.473, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [252.222, 'male_B', 'app', 'neighbour', '']
# Adding event: [258.735, 'male_B', 'app', 'neighbour', '']
# Adding event: [265.557, 'male_B', 'app', 'neighbour', '']
# Adding event: [266.792, 'male_B', 'app', 'neighbour', '']
# Adding event: [271.917, 'male_B', 'app', 'neighbour', '']
# Adding event: [289.323, 'male_B', 'app', 'neighbour', '']
# Adding event: [299.636, 'male_B', 'app', 'neighbour', '']
# Adding event: [308.954, 'male_B', 'app', 'neighbour', '']
# Adding event: [312.655, 'male_B', 'app', 'neighbour', '']
# Adding event: [321.89, 'male_B', 'app', 'neighbour', '']
# Adding event: [370.149, 'male_B', 'app', 'neighbour', '']
# Adding event: [374.557, 'male_B', 'app', 'neighbour', '']
# Adding event: [376.609, 'male_B', 'app', 'neighbour', '']
# Adding event: [377.805, 'female_A', 'ST', 'neighbour', '']
# Adding event: [381.116, 'male_B', 'app', 'neighbour', '']
# Adding event: [383.5, 'male_B', 'app', 'neighbour', '']
# Adding event: [390.21, 'male_B', 'app', 'neighbour', '']
# Adding event: [390.829, 'female_B', 'app', 'neighbour', '']
# Adding event: [418.684, 'male_B', 'ST', 'neighbour', '']
# Adding event: [429.139, 'male_B', 'app', 'partner', '']
# Adding event: [457.767, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [459.863, 'male_B', 'ST', 'neighbour', '']
# Adding event: [472.59, 'male_B', 'bars', 'neighbour', '']
# Adding event: [517.907, 'female_B', 'app', 'neighbour', '']
# Adding event: [545.676, 'male_B', 'app', 'neighbour', '']
# Adding event: [549.951, 'female_B', 'app', 'neighbour', '']
# Adding event: [552.001, 'female_B', 'app', 'neighbour', '']
# Found pair event: [553.119, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [553.119, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [553.119, 'female_A', 'fspr', 'neighbour', '']
# Found pair event: [553.119, 'pair_B', 'app', 'neighbour', '']
# Adding event: [553.119, 'male_B', 'app', 'neighbour', '']
# Adding event: [553.119, 'female_B', 'app', 'neighbour', '']
# Found pair event: [554.452, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [554.452, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [554.452, 'female_A', 'fspr', 'neighbour', '']
# Found pair event: [554.452, 'pair_B', 'app', 'neighbour', '']
# Adding event: [554.452, 'male_B', 'app', 'neighbour', '']
# Adding event: [554.452, 'female_B', 'app', 'neighbour', '']
# Found pair event: [555.529, 'pair_B', 'app', 'neighbour', '']
# Adding event: [555.529, 'male_B', 'app', 'neighbour', '']
# Adding event: [555.529, 'female_B', 'app', 'neighbour', '']
# Found pair event: [556.204, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [556.204, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [556.204, 'female_A', 'fspr', 'neighbour', '']
# Found pair event: [557.021, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [557.021, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [557.021, 'female_A', 'fspr', 'neighbour', '']
# Found pair event: [557.021, 'pair_B', 'app', 'neighbour', '']
# Adding event: [557.021, 'male_B', 'app', 'neighbour', '']
# Adding event: [557.021, 'female_B', 'app', 'neighbour', '']
# Found pair event: [558.469, 'pair_A', 'app', 'neighbour', '']
# Adding event: [558.469, 'male_A', 'app', 'neighbour', '']
# Adding event: [558.469, 'female_A', 'app', 'neighbour', '']
# Found pair event: [558.469, 'pair_B', 'app', 'neighbour', '']
# Adding event: [558.469, 'male_B', 'app', 'neighbour', '']
# Adding event: [558.469, 'female_B', 'app', 'neighbour', '']
# Found pair event: [559.381, 'pair_A', 'app', 'neighbour', '']
# Adding event: [559.381, 'male_A', 'app', 'neighbour', '']
# Adding event: [559.381, 'female_A', 'app', 'neighbour', '']
# Found pair event: [559.381, 'pair_B', 'app', 'neighbour', '']
# Adding event: [559.381, 'male_B', 'app', 'neighbour', '']
# Adding event: [559.381, 'female_B', 'app', 'neighbour', '']
# Found pair event: [560.263, 'pair_B', 'app', 'neighbour', '']
# Adding event: [560.263, 'male_B', 'app', 'neighbour', '']
# Adding event: [560.263, 'female_B', 'app', 'neighbour', '']
# Adding event: [561.463, 'female_A', 'fspr', 'neighbour', '']
# Found pair event: [561.463, 'pair_B', 'app', 'neighbour', '']
# Adding event: [561.463, 'male_B', 'app', 'neighbour', '']
# Adding event: [561.463, 'female_B', 'app', 'neighbour', '']
# Adding event: [562.79, 'male_A', 'hd', 'neighbour', '']
# Found pair event: [562.79, 'pair_B', 'app', 'neighbour', '']
# Adding event: [562.79, 'male_B', 'app', 'neighbour', '']
# Adding event: [562.79, 'female_B', 'app', 'neighbour', '']
# Adding event: [564.349, 'male_B', 'app', 'neighbour', '']
# Adding event: [565.069, 'female_A', 'app', 'neighbour', '']
# Adding event: [568.419, 'female_B', 'app', 'neighbour', '']
# Found pair event: [569.416, 'pair_B', 'app', 'neighbour', '']
# Adding event: [569.416, 'male_B', 'app', 'neighbour', '']
# Adding event: [569.416, 'female_B', 'app', 'neighbour', '']
# Adding event: [570.063, 'female_A', 'app', 'neighbour', '']
# Adding event: [570.063, 'male_A', 'fspr', 'neighbour', '']
# Found pair event: [572.214, 'pair_B', 'app', 'neighbour', '']
# Adding event: [572.214, 'male_B', 'app', 'neighbour', '']
# Adding event: [572.214, 'female_B', 'app', 'neighbour', '']
# Found pair event: [573.405, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [573.405, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [573.405, 'female_A', 'fspr', 'neighbour', '']
# Found pair event: [573.914, 'pair_B', 'app', 'neighbour', '']
# Adding event: [573.914, 'male_B', 'app', 'neighbour', '']
# Adding event: [573.914, 'female_B', 'app', 'neighbour', '']
# Found pair event: [574.57, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [574.57, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [574.57, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [576.658, 'male_B', 'app', 'neighbour', '']
# Found pair event: [577.329, 'pair_A', 'app', 'neighbour', '']
# Adding event: [577.329, 'male_A', 'app', 'neighbour', '']
# Adding event: [577.329, 'female_A', 'app', 'neighbour', '']
# Adding event: [578.284, 'male_B', 'app', 'neighbour', '']
# Adding event: [581.053, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [581.053, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [582.257, 'male_B', 'app', 'neighbour', '']
# Adding event: [586.379, 'male_B', 'app', 'neighbour', '']
# Change             F6 25.06. experiment control -> F6 2017.06.25 experiment control
# Adding event: [1.319, '', 'vstart', 'neighbour', '']
# Adding event: [1.33, 'female_A', 'freeze', 'neighbour', '']
# Adding event: [1.33, 'female_B', 'freeze', 'neighbour', '']
# Adding event: [1.33, 'male_A', 'freeze', 'neighbour', '']
# Adding event: [1.33, 'male_B', 'freeze', 'neighbour', '']
# Adding event: [4.801, 'male_B', 'freeze', 'neighbour', '']
# Adding event: [39.603, 'female_B', 'freeze', 'neighbour', '']
# Adding event: [100.964, 'female_A', 'freeze', 'neighbour', '']
# Adding event: [106.654, 'male_A', 'freeze', 'neighbour', '']
# Adding event: [116.252, 'male_B', 'app', 'neighbour', '']
# Adding event: [116.659, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [125.468, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [128.884, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [130.328, 'female_B', 'fspr', 'neighbour', '']
# Found pair event: [142.065, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [142.065, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [142.065, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [159.674, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [172.825, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [175.154, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [183.567, 'male_B', 'app', 'neighbour', '']
# Adding event: [186.258, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [206.675, 'female_A', 'app', 'partner', '']
# Adding event: [214.906, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [219.117, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [225.84, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [244.129, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [244.721, 'female_A', 'fspr', 'partner', '']
# Adding event: [248.557, 'male_A', 'app', 'neighbour', '']
# Adding event: [250.919, 'male_B', 'app', 'neighbour', '']
# Adding event: [252.203, 'female_A', 'fspr', 'partner', '']
# Adding event: [275.298, 'male_B', 'app', 'partner', '']
# Adding event: [281.616, 'male_B', 'app', 'partner', '']
# Adding event: [285.943, 'male_B', 'app', 'neighbour', '']
# Adding event: [287.442, 'male_A', 'app', 'neighbour', '']
# Adding event: [293.068, 'female_A', 'app', 'partner', '']
# Adding event: [293.695, 'male_A', 'app', 'neighbour', '']
# Adding event: [298.713, 'female_A', 'app', 'neighbour', '']
# Adding event: [299.773, 'male_B', 'app', 'neighbour', '']
# Adding event: [322.084, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [324.092, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [342.403, 'female_A', 'app', 'neighbour', '']
# Adding event: [343.614, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [343.614, 'male_B', 'app', 'neighbour', '']
# Adding event: [345.127, 'male_A', 'app', 'neighbour', '']
# Adding event: [348.179, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [350.881, 'male_A', 'app', 'neighbour', '']
# Adding event: [352.47, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [354.046, 'male_A', 'app', 'neighbour', '']
# Adding event: [357.689, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [359.993, 'male_B', 'fspr', 'partner', '']
# Found pair event: [362.233, 'pair_B', 'app', 'neighbour', '']
# Adding event: [362.233, 'male_B', 'app', 'neighbour', '']
# Adding event: [362.233, 'female_B', 'app', 'neighbour', '']
# Adding event: [371.306, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [378.762, 'male_A', 'fspr', 'partner', '']
# Adding event: [382.697, 'male_B', 'app', 'neighbour', '']
# Adding event: [384.441, 'male_A', 'sbend', 'neighbour', '']
# Adding event: [385.276, 'female_A', 'app', 'neighbour', '']
# Adding event: [386.493, 'male_A', 'app', 'neighbour', '']
# Adding event: [390.115, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [394.098, 'male_A', 'fspr', 'partner', '']
# Adding event: [395.345, 'male_A', 'app', 'neighbour', '']
# Adding event: [396.242, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [402.473, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [406.252, 'male_A', 'app', 'neighbour', '']
# Adding event: [407.257, 'female_A', 'app', 'neighbour', '']
# Adding event: [408.054, 'male_A', 'app', 'neighbour', '']
# Adding event: [408.054, 'male_B', 'app', 'neighbour', '']
# Adding event: [413.994, 'male_A', 'app', 'neighbour', '']
# Adding event: [417.288, 'male_A', 'app', 'neighbour', '']
# Adding event: [418.978, 'male_A', 'app', 'neighbour', '']
# Adding event: [420.203, 'male_B', 'app', 'neighbour', '']
# Found pair event: [421.77, 'pair_A', 'app', 'neighbour', '']
# Adding event: [421.77, 'male_A', 'app', 'neighbour', '']
# Adding event: [421.77, 'female_A', 'app', 'neighbour', '']
# Adding event: [422.273, 'male_B', 'app', 'neighbour', '']
# Adding event: [424.538, 'male_B', 'app', 'neighbour', '']
# Adding event: [426.932, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [426.932, 'male_A', 'app', 'neighbour', '']
# Found pair event: [436.19, 'pair_A', 'app', 'neighbour', '']
# Adding event: [436.19, 'male_A', 'app', 'neighbour', '']
# Adding event: [436.19, 'female_A', 'app', 'neighbour', '']
# Adding event: [439.693, 'male_B', 'app', 'neighbour', '']
# Found pair event: [442.056, 'pair_A', 'app', 'neighbour', '']
# Adding event: [442.056, 'male_A', 'app', 'neighbour', '']
# Adding event: [442.056, 'female_A', 'app', 'neighbour', '']
# Adding event: [444.667, 'male_A', 'app', 'neighbour', '']
# Adding event: [446.743, 'female_A', 'app', 'neighbour', '']
# Adding event: [447.852, 'male_A', 'app', 'neighbour', '']
# Adding event: [450.754, 'male_A', 'app', 'neighbour', '']
# Adding event: [453.269, 'female_A', 'app', 'neighbour', '']
# Adding event: [462.744, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [462.744, 'male_A', 'app', 'neighbour', '']
# Adding event: [464.769, 'male_A', 'app', 'neighbour', '']
# Adding event: [468.781, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [470.186, 'male_A', 'app', 'neighbour', '']
# Adding event: [471.074, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [472.135, 'female_A', 'app', 'neighbour', '']
# Adding event: [474.749, 'male_A', 'app', 'neighbour', '']
# Adding event: [475.577, 'female_A', 'app', 'neighbour', '']
# Adding event: [478.163, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [478.163, 'male_A', 'app', 'neighbour', '']
# Found pair event: [479.877, 'pair_A', 'app', 'neighbour', '']
# Adding event: [479.877, 'male_A', 'app', 'neighbour', '']
# Adding event: [479.877, 'female_A', 'app', 'neighbour', '']
# Adding event: [485.794, 'male_A', 'app', 'neighbour', '']
# Adding event: [491.476, 'female_A', 'app', 'neighbour', '']
# Adding event: [494.015, 'male_A', 'app', 'neighbour', '']
# Adding event: [495.13, 'male_A', 'app', 'neighbour', '']
# Adding event: [495.829, 'female_A', 'app', 'neighbour', '']
# Adding event: [495.829, 'female_B', 'app', 'neighbour', '']
# Adding event: [497.441, 'male_A', 'app', 'neighbour', '']
# Adding event: [500.094, 'female_A', 'app', 'neighbour', '']
# Adding event: [500.751, 'male_A', 'app', 'neighbour', '']
# Adding event: [503.124, 'female_B', 'app', 'neighbour', '']
# Adding event: [504.457, 'female_A', 'app', 'neighbour', '']
# Adding event: [505.169, 'male_A', 'app', 'neighbour', '']
# Adding event: [509.03, 'male_A', 'app', 'neighbour', '']
# Adding event: [509.898, 'female_B', 'app', 'neighbour', '']
# Adding event: [513.12, 'male_A', 'app', 'neighbour', '']
# Adding event: [514.969, 'female_A', 'app', 'neighbour', '']
# Adding event: [519.094, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [525.088, 'female_B', 'app', 'neighbour', '']
# Found pair event: [526.162, 'pair_A', 'fspr', 'neighbour', '']
# Adding event: [526.162, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [526.162, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [529.318, 'female_A', 'app', 'neighbour', '']
# Adding event: [532.684, 'male_A', 'app', 'neighbour', '']
# Adding event: [536.231, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [536.231, 'male_A', 'app', 'neighbour', '']
# Adding event: [537.542, 'female_A', 'app', 'neighbour', '']
# Adding event: [544.9, 'female_B', 'app', 'neighbour', '']
# Found pair event: [545.357, 'pair_A', 'app', 'neighbour', '']
# Adding event: [545.357, 'male_A', 'app', 'neighbour', '']
# Adding event: [545.357, 'female_A', 'app', 'neighbour', '']
# Found pair event: [548.256, 'pair_A', 'app', 'neighbour', '']
# Adding event: [548.256, 'male_A', 'app', 'neighbour', '']
# Adding event: [548.256, 'female_A', 'app', 'neighbour', '']
# Adding event: [551.665, 'male_A', 'app', 'neighbour', '']
# Adding event: [556.028, 'female_B', 'app', 'neighbour', '']
# Adding event: [559.94, 'male_A', 'app', 'neighbour', '']
# Adding event: [567.45, 'male_A', 'app', 'neighbour', '']
# Adding event: [572.374, 'male_A', 'app', 'neighbour', '']
# Adding event: [578.961, 'female_A', 'app', 'neighbour', '']
# Adding event: [578.961, 'female_B', 'app', 'neighbour', '']
# Adding event: [580.817, 'male_A', 'app', 'neighbour', '']
# Adding event: [583.692, 'female_B', 'app', 'neighbour', '']
# Found pair event: [583.692, 'pair_A', 'app', 'neighbour', '']
# Adding event: [583.692, 'male_A', 'app', 'neighbour', '']
# Adding event: [583.692, 'female_A', 'app', 'neighbour', '']
# Adding event: [589.183, 'female_A', 'app', 'neighbour', '']
# Adding event: [589.843, 'male_A', 'app', 'neighbour', '']
# Adding event: [591.62, 'male_A', 'app', 'neighbour', '']
# Adding event: [594.62, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [595.359, 'female_A', 'app', 'neighbour', '']
# Adding event: [599.894, 'male_A', 'app', 'neighbour', '']
# Adding event: [609.942, 'female_B', 'app', 'neighbour', '']
# Adding event: [613.808, 'male_A', 'app', 'neighbour', '']
# Found pair event: [615.772, 'pair_A', 'app', 'neighbour', '']
# Adding event: [615.772, 'male_A', 'app', 'neighbour', '']
# Adding event: [615.772, 'female_A', 'app', 'neighbour', '']
# Adding event: [620.267, 'female_A', 'app', 'neighbour', '']
# Adding event: [620.267, 'female_B', 'app', 'neighbour', '']
# Adding event: [623.485, 'male_A', 'app', 'neighbour', '']
# Found pair event: [632.088, 'pair_A', 'app', 'neighbour', '']
# Adding event: [632.088, 'male_A', 'app', 'neighbour', '']
# Adding event: [632.088, 'female_A', 'app', 'neighbour', '']
# Adding event: [634.268, 'female_B', 'app', 'neighbour', '']
# Adding event: [638.896, 'female_B', 'app', 'neighbour', '']
# Found pair event: [640.421, 'pair_A', 'app', 'neighbour', '']
# Adding event: [640.421, 'male_A', 'app', 'neighbour', '']
# Adding event: [640.421, 'female_A', 'app', 'neighbour', '']
# Adding event: [653.066, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [665.07, 'female_B', 'app', 'neighbour', '']
# Adding event: [665.644, 'female_A', 'app', 'neighbour', '']
# Adding event: [666.892, 'male_A', 'app', 'neighbour', '']
# Adding event: [674.848, 'female_B', 'app', 'neighbour', '']
# Adding event: [675.287, 'female_A', 'app', 'neighbour', '']
# Adding event: [678.91, 'male_A', 'app', 'neighbour', '']
# Adding event: [686.175, 'female_A', 'app', 'neighbour', '']
# Adding event: [686.175, 'female_B', 'app', 'neighbour', '']
# Adding event: [687.685, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [688.719, 'male_A', 'app', 'neighbour', '']
# Adding event: [689.366, 'female_B', 'app', 'neighbour', '']
# Adding event: [691.472, 'female_A', 'sbend', 'neighbour', '']
# ...
# Adding event: [456.269, 'male_B', 'app', 'neighbour', '']
# Adding event: [459.127, 'female_A', 'app', 'neighbour', '']
# Adding event: [459.127, 'male_B', 'app', 'neighbour', '']
# Adding event: [465.683, 'male_B', 'app', 'neighbour', '']
# Adding event: [466.379, 'female_A', 'app', 'neighbour', '']
# Adding event: [468.962, 'male_B', 'fspr', 'neighbour', '']
# Found pair event: [473.484, 'pair_B', 'app', 'neighbour', '']
# Adding event: [473.484, 'male_B', 'app', 'neighbour', '']
# Adding event: [473.484, 'female_B', 'app', 'neighbour', '']
# Adding event: [477.463, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [479.816, 'female_B', 'app', 'neighbour', '']
# Adding event: [483.177, 'male_B', 'app', 'neighbour', '']
# Adding event: [484.28, 'female_B', 'app', 'neighbour', '']
# Adding event: [488.672, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [490.413, 'female_B', 'app', 'neighbour', '']
# Adding event: [502.114, 'female_B', 'app', 'neighbour', '']
# Found pair event: [502.843, 'pair_B', 'app', 'neighbour', '']
# Adding event: [502.843, 'male_B', 'app', 'neighbour', '']
# Adding event: [502.843, 'female_B', 'app', 'neighbour', '']
# Adding event: [503.106, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [506.783, 'male_B', 'app', 'neighbour', '']
# Found pair event: [507.87, 'pair_B', 'app', 'neighbour', '']
# Adding event: [507.87, 'male_B', 'app', 'neighbour', '']
# Adding event: [507.87, 'female_B', 'app', 'neighbour', '']
# Adding event: [510.775, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [512.779, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [513.807, 'female_A', 'app', 'neighbour', '']
# Adding event: [514.904, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [521.888, 'male_B', 'app', 'neighbour', '']
# Adding event: [523.732, 'female_B', 'app', 'neighbour', '']
# Found pair event: [526.173, 'pair_B', 'sbend', 'neighbour', '']
# Adding event: [526.173, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [526.173, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [528.762, 'female_A', 'app', 'neighbour', '']
# Adding event: [530.539, 'male_B', 'app', 'neighbour', '']
# Adding event: [531.233, 'female_A', 'app', 'neighbour', '']
# Adding event: [532.558, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [533.578, 'male_B', 'app', 'neighbour', '']
# Adding event: [534.88, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [535.994, 'male_B', 'app', 'neighbour', '']
# Adding event: [539.708, 'male_B', 'app', 'neighbour', '']
# Adding event: [540.209, 'female_A', 'app', 'neighbour', '']
# Adding event: [541.473, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [542.166, 'female_A', 'app', 'neighbour', '']
# Adding event: [543.71, 'male_B', 'app', 'neighbour', '']
# Adding event: [546.253, 'male_B', 'app', 'neighbour', '']
# Adding event: [548.975, 'male_B', 'app', 'neighbour', '']
# Adding event: [550.281, 'female_A', 'app', 'neighbour', '']
# Adding event: [551.372, 'female_A', 'app', 'neighbour', '']
# Found pair event: [553.486, 'pair_B', 'fspr', 'neighbour', '']
# Adding event: [553.486, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [553.486, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [555.852, 'female_A', 'app', 'neighbour', '']
# Adding event: [558.738, 'male_B', 'app', 'neighbour', '']
# Adding event: [562.65, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [565.533, 'female_A', 'app', 'neighbour', '']
# Adding event: [568.076, 'male_B', 'app', 'neighbour', '']
# Adding event: [569.083, 'female_A', 'sbend', 'neighbour', '']
# Found pair event: [571.382, 'pair_B', 'app', 'neighbour', '']
# Adding event: [571.382, 'male_B', 'app', 'neighbour', '']
# Adding event: [571.382, 'female_B', 'app', 'neighbour', '']
# Adding event: [574.41, 'male_B', 'app', 'neighbour', '']
# Adding event: [575.108, 'female_A', 'app', 'neighbour', '']
# Adding event: [575.108, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [579.556, 'female_A', 'app', 'neighbour', '']
# Found pair event: [581.334, 'pair_B', 'sbend', 'neighbour', '']
# Adding event: [581.334, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [581.334, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [582.044, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [587.703, 'male_A', 'app', 'neighbour', '']
# Adding event: [590.967, 'male_A', 'app', 'neighbour', '']
# Adding event: [593.176, 'female_A', 'app', 'neighbour', '']
# Adding event: [597.921, 'female_A', 'app', 'neighbour', '']
# Adding event: [598.608, 'male_A', 'app', 'neighbour', '']
# Found pair event: [599.226, 'pair_B', 'sbend', 'neighbour', '']
# Adding event: [599.226, 'male_B', 'sbend', 'neighbour', '']
# Adding event: [599.226, 'female_B', 'sbend', 'neighbour', '']
# Adding event: [602.381, 'female_A', 'app', 'neighbour', '']
# Adding event: [604.49, 'male_B', 'app', 'neighbour', '']
# Adding event: [610.004, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [610.68, 'female_A', 'app', 'neighbour', '']
# Adding event: [612.78, 'female_B', 'app', 'neighbour', '']
# Adding event: [615.582, 'male_B', 'app', 'neighbour', '']
# Adding event: [616.169, 'male_A', 'app', 'neighbour', '']
# Found pair event: [617.048, 'pair_B', 'fspr', 'neighbour', '']
# Adding event: [617.048, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [617.048, 'female_B', 'fspr', 'neighbour', '']
# Change             F5 25.06. experiment control -> F5 2017.06.25 experiment control
# Adding event: [1.75, '', 'vstart', 'neighbour', '']
# Adding event: [1.752, 'female_A', 'freeze', 'neighbour', '']
# Adding event: [1.752, 'female_B', 'freeze', 'neighbour', '']
# Adding event: [1.752, 'male_A', 'freeze', 'neighbour', '']
# Adding event: [1.752, 'male_B', 'freeze', 'neighbour', '']
# Adding event: [6.692, 'male_B', 'freeze', 'neighbour', '']
# Adding event: [7.322, 'male_A', 'freeze', 'neighbour', '']
# Adding event: [15.811, 'female_A', 'freeze', 'neighbour', '']
# Adding event: [21.727, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [38.742, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [40.96, 'male_B', 'app', 'neighbour', '']
# Adding event: [44.34, 'male_B', 'app', 'neighbour', '']
# Found pair event: [46.98, 'pair_A', 'app', 'neighbour', '']
# Adding event: [46.98, 'male_A', 'app', 'neighbour', '']
# Adding event: [46.98, 'female_A', 'app', 'neighbour', '']
# Adding event: [51.796, 'female_B', 'freeze', 'neighbour', '']
# Adding event: [68.017, 'female_A', 'app', 'neighbour', '']
# Adding event: [70.125, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [70.125, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [71.417, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [73.748, 'female_B', 'app', 'neighbour', '']
# Adding event: [79.19, 'male_A', 'cavity', 'neighbour', '']
# Adding event: [79.19, 'male_B', 'cavity', 'neighbour', '']
# Adding event: [81.368, 'female_B', 'app', 'partner', '']
# Adding event: [84.484, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [88.07, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [117.477, 'female_B', 'app', 'neighbour', '']
# Adding event: [118.47, 'male_A', 'app', 'neighbour', '']
# Adding event: [119.89, 'male_B', 'app', 'neighbour', '']
# Adding event: [121.113, 'female_A', 'app', 'neighbour', '']
# Adding event: [121.113, 'female_B', 'app', 'neighbour', '']
# Adding event: [122.598, 'female_B', 'app', 'neighbour', '']
# Adding event: [135.471, 'male_B', 'app', 'neighbour', '']
# Adding event: [137.243, 'female_A', 'app', 'neighbour', '']
# Found pair event: [140.158, 'pair_B', 'app', 'neighbour', '']
# Adding event: [140.158, 'male_B', 'app', 'neighbour', '']
# Adding event: [140.158, 'female_B', 'app', 'neighbour', '']
# Adding event: [142.851, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [156.582, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [157.461, 'female_A', 'app', 'neighbour', '']
# Adding event: [158.456, 'male_A', 'app', 'neighbour', '']
# Adding event: [158.456, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [189.573, 'female_B', 'app', 'neighbour', '']
# Adding event: [190.258, 'male_B', 'app', 'neighbour', '']
# Adding event: [192.878, 'male_A', 'fspr', 'partner', '']
# Adding event: [197.417, 'female_B', 'app', 'neighbour', '']
# Adding event: [200.519, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [205.782, 'male_B', 'app', 'neighbour', '']
# Adding event: [206.642, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [211.73, 'male_B', 'fspr', 'partner', '']
# Adding event: [212.623, 'female_B', 'fspr', 'partner', '']
# Adding event: [214.945, 'male_B', 'app', 'neighbour', '']
# Adding event: [217.963, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [218.815, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [218.815, 'female_B', 'app', 'neighbour', '']
# Adding event: [223.256, 'female_B', 'app', 'neighbour', '']
# Adding event: [225.181, 'male_A', 'fspr', 'partner', '']
# Adding event: [229.923, 'female_A', 'app', 'neighbour', '']
# Found pair event: [230.602, 'pair_B', 'app', 'neighbour', '']
# Adding event: [230.602, 'male_B', 'app', 'neighbour', '']
# Adding event: [230.602, 'female_B', 'app', 'neighbour', '']
# Adding event: [235.802, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [247.222, 'female_B', 'app', 'neighbour', '']
# Adding event: [247.222, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [248.406, 'male_A', 'app', 'neighbour', '']
# Adding event: [253.059, 'male_B', 'app', 'neighbour', '']
# Adding event: [254.721, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [261.381, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [263.685, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [283.058, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [290.312, 'female_B', 'app', 'neighbour', '']
# Adding event: [296.046, 'male_B', 'app', 'neighbour', '']
# Adding event: [297.543, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [300.16, 'male_B', 'app', 'neighbour', '']
# Adding event: [301.099, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [309.264, 'female_B', 'app', 'neighbour', '']
# Adding event: [310.268, 'male_A', 'app', 'neighbour', '']
# Adding event: [311.778, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [312.661, 'female_A', 'app', 'neighbour', '']
# Adding event: [313.276, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [316.219, 'male_B', 'app', 'neighbour', '']
# Adding event: [324.662, 'male_B', 'app', 'neighbour', '']
# Adding event: [326.359, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [328.72, 'male_B', 'app', 'neighbour', '']
# Adding event: [330.263, 'male_A', 'app', 'neighbour', '']
# Adding event: [331.232, 'female_B', 'app', 'neighbour', '']
# Adding event: [336.016, 'male_B', 'app', 'neighbour', '']
# Adding event: [347.522, 'male_B', 'app', 'neighbour', '']
# Adding event: [350.488, 'female_A', 'app', 'neighbour', '']
# Adding event: [354.473, 'female_B', 'fspr', 'partner', '']
# Adding event: [354.473, 'male_B', 'fspr', 'partner', '']
# Adding event: [355.572, 'female_B', 'app', 'neighbour', '']
# Adding event: [358.16, 'female_B', 'app', 'partner', '']
# Adding event: [359.231, 'male_B', 'fspr', 'partner', '']
# Adding event: [361.532, 'male_A', 'fspr', 'neighbour', '']
# Found pair event: [361.532, 'pair_B', 'app', 'neighbour', '']
# Adding event: [361.532, 'male_B', 'app', 'neighbour', '']
# Adding event: [361.532, 'female_B', 'app', 'neighbour', '']
# Adding event: [369.909, 'male_B', 'app', 'neighbour', '']
# Adding event: [376.578, 'male_B', 'app', 'neighbour', '']
# Adding event: [378.623, 'female_B', 'app', 'neighbour', '']
# Adding event: [379.828, 'male_A', 'app', 'neighbour', '']
# Adding event: [380.334, 'female_A', 'app', 'neighbour', '']
# Found pair event: [381.53, 'pair_B', 'app', 'neighbour', '']
# Adding event: [381.53, 'male_B', 'app', 'neighbour', '']
# Adding event: [381.53, 'female_B', 'app', 'neighbour', '']
# Found pair event: [383.017, 'pair_A', 'app', 'neighbour', '']
# Adding event: [383.017, 'male_A', 'app', 'neighbour', '']
# Adding event: [383.017, 'female_A', 'app', 'neighbour', '']
# Adding event: [387.574, 'male_B', 'app', 'neighbour', '']
# Adding event: [389.14, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [392.403, 'male_A', 'app', 'neighbour', '']
# Adding event: [392.979, 'female_B', 'fspr', 'neighbour', '']
# Found pair event: [394.498, 'pair_B', 'app', 'neighbour', '']
# Adding event: [394.498, 'male_B', 'app', 'neighbour', '']
# Adding event: [394.498, 'female_B', 'app', 'neighbour', '']
# Found pair event: [395.694, 'pair_A', 'app', 'neighbour', '']
# Adding event: [395.694, 'male_A', 'app', 'neighbour', '']
# Adding event: [395.694, 'female_A', 'app', 'neighbour', '']
# Adding event: [396.924, 'female_B', 'app', 'neighbour', '']
# Adding event: [396.924, 'male_A', 'app', 'neighbour', '']
# Adding event: [398.042, 'male_A', 'app', 'neighbour', '']
# Adding event: [398.592, 'female_A', 'sbend', 'neighbour', '']
# Adding event: [405.144, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [425.796, 'female_A', 'app', 'neighbour', '']
# Adding event: [426.426, 'male_B', 'app', 'neighbour', '']
# Adding event: [430.584, 'male_B', 'app', 'neighbour', '']
# Adding event: [431.34, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [441.45, 'female_B', 'app', 'neighbour', '']
# Adding event: [445.878, 'male_B', 'fspr', 'neighbour', '']
# Found pair event: [453.694, 'pair_B', 'app', 'neighbour', '']
# Adding event: [453.694, 'male_B', 'app', 'neighbour', '']
# Adding event: [453.694, 'female_B', 'app', 'neighbour', '']
# Adding event: [454.369, 'female_A', 'hd', 'neighbour', '']
# Adding event: [456.126, 'male_B', 'app', 'neighbour', '']
# Adding event: [465.864, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [470.506, 'male_B', 'app', 'neighbour', '']
# Adding event: [474.116, 'male_B', 'app', 'neighbour', '']
# Adding event: [475.689, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [476.597, 'male_B', 'app', 'neighbour', '']
# Adding event: [477.263, 'female_B', 'app', 'neighbour', '']
# Adding event: [489.512, 'male_B', 'app', 'neighbour', '']
# Adding event: [490.88, 'male_B', 'app', 'neighbour', '']
# Adding event: [492.062, 'female_B', 'cavity', 'neighbour', '']
# Adding event: [497.211, 'male_B', 'app', 'neighbour', '']
# Adding event: [503.838, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [505.625, 'male_B', 'app', 'neighbour', '']
# Adding event: [526.732, 'female_B', 'app', 'neighbour', '']
# Adding event: [527.477, 'male_B', 'fspr', 'neighbour', '']
# Adding event: [528.158, 'female_A', 'fspr', 'neighbour', '']
# Adding event: [532.24, 'female_B', 'fspr', 'neighbour', '']
# Adding event: [545.694, 'female_B', 'app', 'neighbour', '']
# Adding event: [547.255, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [554.806, 'male_B', 'app', 'neighbour', '']
# Adding event: [557.245, 'female_A', 'cavity', 'neighbour', '']
# Adding event: [560.385, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [563.695, 'male_B', 'app', 'neighbour', '']
# Adding event: [567.14, 'female_A', 'app', 'neighbour', '']
# Adding event: [567.14, 'female_B', 'app', 'neighbour', '']
# Adding event: [568.799, 'male_B', 'app', 'neighbour', '']
# Adding event: [569.43, 'male_A', 'app', 'neighbour', '']
# Adding event: [570.745, 'female_B', 'app', 'neighbour', '']
# Adding event: [571.476, 'female_A', 'app', 'neighbour', '']
# Adding event: [571.476, 'male_B', 'app', 'neighbour', '']
# Adding event: [572.31, 'male_A', 'fspr', 'neighbour', '']
# Adding event: [573.612, 'male_B', 'app', 'neighbour', '']
# Adding event: [575.053, 'female_A', 'app', 'neighbour', '']
# Adding event: [575.053, 'female_B', 'app', 'neighbour', '']
# Adding event: [579.961, 'male_B', 'app', 'neighbour', '']
# Adding event: [582.29, 'female_A', 'app', 'neighbour', '']
# Adding event: [584.509, 'female_B', 'app', 'neighbour', '']
# Adding event: [585.772, 'female_A', 'app', 'neighbour', '']
# Adding event: [585.772, 'male_B', 'fspr', 'neighbour', '']
# Found pair event: [587.023, 'pair_B', 'app', 'neighbour', '']
# Adding event: [587.023, 'male_B', 'app', 'neighbour', '']
# Adding event: [587.023, 'female_B', 'app', 'neighbour', '']
# Adding event: [587.839, 'female_A', 'app', 'neighbour', '']
# Adding event: [590.495, 'female_A', 'app', 'neighbour', '']
# Adding event: [592.094, 'female_B', 'app', 'neighbour', '']
# Adding event: [593.145, 'male_B', 'app', 'neighbour', '']

# %%
print(f'Have {len(observations)} valid observations')
# Out:
# Have 79 valid observations

# %% [markdown]
# This is where the fun stuff really starts, so initially we have some basic scaffolding code, although with the definition of two different kinds of latency, `max_latency` and `base_latency`.  We also define a `CombiningData` type; this is the combination of the observation id plus the subject.  The output data has one row for each unique `CombiningData`.  The `get_first_occurance_timestamp` searches a list of events until both the subject and recipient are matched.

# %%
max_latency = 1000000
base_latency = 120

class CombiningData(namedtuple('CombiningData', ['obs_id', 'subject'])):
    def get_csv(self):
        return '{}, {}, {}, {}, {}'.format(*self.obs_id.split(' '), self.subject)

def get_first_occurance_timestamp(subject, recipient, events):
    for event in events:
        if event.type == 'vstart':
            continue
        if event.recipient == recipient and event.subject == subject:
           return event.timestamp
    return max_latency

# %% [markdown]
# The `GetLatency` class takes a list of events and determines the timestamp of the first event for each combination subject and recipient.  We are not interested in any events involving the partner, only intruder and neighbour.  If there is no event in the list for any subject and recipient pair, then insert a "maximum latency"; this is the lowest latency of all combinations for this list of events plus the "base latency", which was specified in the previous cell (`base_latency`).

# %%
class GetLatency:
    def __init__(self, events):
        # generate a list of the slots and get the first timestamp for each.
        tuples = [(x, y, f'{x}_{y}') for x in ['male_A', 'female_A', 'male_B', 'female_B'] for y in ['partner', 'neighbour']]
        for t in tuples:
            setattr(self, t[2], get_first_occurance_timestamp(t[0], t[1], events))

        # now for all events in this observation calculate the minimal latency.
        min_latency = min(map(lambda x: getattr(self, x[2]), tuples))

        # check that every observation has a minimum latency
        assert min_latency != max_latency, events
        
        # cap all latencies, if there is no event in this observation then
        # get_first_occurance_timestamp returns a very large latency which is
        # definitely going to be much much larger than base_latency plus min_latency.
        for t in tuples:
            setattr(self, t[2], min(base_latency + min_latency, getattr(self, t[2])))

# %% [markdown]
# Now that we have the scaffolding setup this is a straightforward traverse of the data generating a dictionary of `CombiningData` to latencies, called `latencies` (not very original).  For each `CombiningData` there are two latencies, the intruder latency and the neighbour latency.  So for each observation we should be entering four entries into `latencies`.

# %%
Latency = namedtuple('Latency', ['partner', 'neighbour'])

latencies = dict()

for label, events in observations.items():
    latency = GetLatency(events)

    if verbose:
        print(f'{label}, m, {latency.male_A_partner}, {latency.male_A_neighbour}')
        print(f'{label}, f, {latency.female_A_partner}, {latency.female_A_neighbour}')
        print(f'{label}, nm, {latency.male_B_partner}, {latency.male_B_neighbour}')
        print(f'{label}, nf, {latency.female_B_partner}, {latency.female_B_neighbour}')

    # store latencies for next step
    latencies[CombiningData(label, 'male_A')] = Latency(latency.male_A_partner, latency.male_A_neighbour)
    latencies[CombiningData(label, 'female_A')] = Latency(latency.female_A_partner, latency.female_A_neighbour)
    latencies[CombiningData(label, 'male_B')] = Latency(latency.male_B_partner, latency.male_B_neighbour)
    latencies[CombiningData(label, 'female_B')] = Latency(latency.female_B_partner, latency.female_B_neighbour)
# Out:
# F5 2017.06.09 habituation control, m, 44.545, 84.266
# F5 2017.06.09 habituation control, f, 158.312, 78.352
# F5 2017.06.09 habituation control, nm, 90.3, 137.582
# F5 2017.06.09 habituation control, nf, 66.898, 38.312
# F6 2017.07.15 habituation treatment, m, 124.414, 42.802
# F6 2017.07.15 habituation treatment, f, 80.38, 22.11
# F6 2017.07.15 habituation treatment, nm, 35.756, 124.414
# F6 2017.07.15 habituation treatment, nf, 4.414, 38.464
# F5 2017.04.14 habituation control, m, 121.933, 52.746
# F5 2017.04.14 habituation control, f, 121.933, 52.746
# F5 2017.04.14 habituation control, nm, 121.933, 51.655
# F5 2017.04.14 habituation control, nf, 121.933, 1.9330000000000003
# F5 2017.04.28 habituation control, m, 123.101, 123.101
# F5 2017.04.28 habituation control, f, 123.101, 123.101
# F5 2017.04.28 habituation control, nm, 123.101, 3.101
# F5 2017.04.28 habituation control, nf, 123.101, 3.655
# F6 2017.06.25 experiment control, m, 120.011, 0.01100000000000012
# F6 2017.06.25 experiment control, f, 120.011, 0.01100000000000012
# F6 2017.06.25 experiment control, nm, 120.011, 0.01100000000000012
# F6 2017.06.25 experiment control, nf, 120.011, 0.01100000000000012
# F1 2017.06.11 experiment treatment, m, 120.0, 0.0
# F1 2017.06.11 experiment treatment, f, 120.0, 0.0
# F1 2017.06.11 experiment treatment, nm, 120.0, 0.0
# F1 2017.06.11 experiment treatment, nf, 120.0, 0.0
# F1 2017.07.09 experiment treatment, m, 120.785, 12.433
# F1 2017.07.09 experiment treatment, f, 120.785, 28.212
# F1 2017.07.09 experiment treatment, nm, 120.785, 120.785
# F1 2017.07.09 experiment treatment, nf, 23.195999999999998, 0.785
# F1 2017.05.09 experiment control, m, 124.668, 4.668
# F1 2017.05.09 experiment control, f, 124.668, 4.668
# F1 2017.05.09 experiment control, nm, 124.668, 4.668
# F1 2017.05.09 experiment control, nf, 124.668, 4.668
# F6 2017.05.09 experiment treatment, m, 125.212, 101.727
# F6 2017.05.09 experiment treatment, f, 125.212, 5.212
# F6 2017.05.09 experiment treatment, nm, 125.212, 5.213
# F6 2017.05.09 experiment treatment, nf, 125.212, 5.213
# F6 2017.05.31 habituation treatment, m, 124.266, 9.367
# F6 2017.05.31 habituation treatment, f, 124.266, 24.583
# F6 2017.05.31 habituation treatment, nm, 124.266, 24.087
# F6 2017.05.31 habituation treatment, nf, 124.266, 4.266
# F6 2017.06.18 experiment treatment, m, 120.0, 0.0
# F6 2017.06.18 experiment treatment, f, 47.741, 0.0
# F6 2017.06.18 experiment treatment, nm, 120.0, 0.0
# F6 2017.06.18 experiment treatment, nf, 120.0, 0.0
# F5 2017.06.11 experiment control, m, 120.0, 0.0
# F5 2017.06.11 experiment control, f, 120.0, 0.0
# F5 2017.06.11 experiment control, nm, 120.0, 0.0
# F5 2017.06.11 experiment control, nf, 120.0, 0.0
# F2 2017.06.24 habituation treatment, m, 144.958, 144.958
# F2 2017.06.24 habituation treatment, f, 144.958, 26.597
# F2 2017.06.24 habituation treatment, nm, 124.137, 87.752
# F2 2017.06.24 habituation treatment, nf, 144.958, 24.958
# F6 2017.05.18 experiment treatment, m, 120.656, 0.6559999999999997
# F6 2017.05.18 experiment treatment, f, 111.59700000000001, 0.6559999999999997
# F6 2017.05.18 experiment treatment, nm, 120.656, 64.754
# F6 2017.05.18 experiment treatment, nf, 120.656, 0.6559999999999997
# F5 2017.04.21 experiment control, m, 120.009, 0.008999999999998565
# F5 2017.04.21 experiment control, f, 120.009, 0.008999999999998565
# F5 2017.04.21 experiment control, nm, 120.009, 0.008999999999998565
# F5 2017.04.21 experiment control, nf, 44.07, 0.008999999999998565
# F6 2017.04.21 experiment control, m, 120.00999999999999, 0.00999999999999801
# F6 2017.04.21 experiment control, f, 1.1219999999999999, 24.383999999999997
# F6 2017.04.21 experiment control, nm, 120.00999999999999, 0.00999999999999801
# F6 2017.04.21 experiment control, nf, 120.00999999999999, 0.00999999999999801
# F1 2017.06.25 experiment treatment, m, 120.001, 0.0009999999999998899
# F1 2017.06.25 experiment treatment, f, 4.756, 0.0009999999999998899
# F1 2017.06.25 experiment treatment, nm, 120.001, 0.0009999999999998899
# F1 2017.06.25 experiment treatment, nf, 120.001, 0.0009999999999998899
# F5 2017.05.07 habituation treatment, m, 176.948, 59.43
# F5 2017.05.07 habituation treatment, f, 176.948, 59.43
# F5 2017.05.07 habituation treatment, nm, 176.948, 60.725
# F5 2017.05.07 habituation treatment, nf, 176.948, 56.948
# F1 2017.07.08 habituation treatment, m, 150.329, 45.976
# F1 2017.07.08 habituation treatment, f, 150.329, 30.328999999999997
# F1 2017.07.08 habituation treatment, nm, 150.329, 48.859
# F1 2017.07.08 habituation treatment, nf, 53.547000000000004, 36.544000000000004
# F6 2017.06.03 experiment treatment, m, 132.541, 132.541
# F6 2017.06.03 experiment treatment, f, 132.541, 132.541
# F6 2017.06.03 experiment treatment, nm, 77.854, 71.625
# F6 2017.06.03 experiment treatment, nf, 78.435, 12.541
# F5 2017.07.15 habituation treatment, m, 86.181, 146.768
# F5 2017.07.15 habituation treatment, f, 86.181, 42.025
# F5 2017.07.15 habituation treatment, nm, 48.667, 26.767999999999997
# F5 2017.07.15 habituation treatment, nf, 30.073999999999998, 45.194
# F5 2017.07.09 experiment control, m, 127.421, 127.421
# F5 2017.07.09 experiment control, f, 127.421, 47.573
# F5 2017.07.09 experiment control, nm, 102.719, 61.318000000000005
# F5 2017.07.09 experiment control, nf, 127.421, 7.421
# F1 2017.05.01 experiment treatment, m, 136.91, 44.824
# F1 2017.05.01 experiment treatment, f, 136.91, 43.243
# F1 2017.05.01 experiment treatment, nm, 92.59, 24.271
# F1 2017.05.01 experiment treatment, nf, 53.718, 16.91
# F5 2017.07.08 habituation control, m, 123.784, 3.7840000000000003
# F5 2017.07.08 habituation control, f, 123.784, 9.194
# F5 2017.07.08 habituation control, nm, 123.784, 123.784
# F5 2017.07.08 habituation control, nf, 123.784, 9.194
# F1 2017.07.15 habituation control, m, 70.931, 126.289
# F1 2017.07.15 habituation control, f, 69.195, 10.931000000000001
# F1 2017.07.15 habituation control, nm, 126.289, 6.289
# F1 2017.07.15 habituation control, nf, 23.336, 14.056000000000001
# F2 2017.05.24 habituation treatment, m, 123.571, 3.58
# F2 2017.05.24 habituation treatment, f, 123.571, 11.659
# F2 2017.05.24 habituation treatment, nm, 123.571, 3.571
# F2 2017.05.24 habituation treatment, nf, 123.571, 5.622999999999999
# F1 2017.07.16 experiment control, m, 120.0, 0.0
# F1 2017.07.16 experiment control, f, 120.0, 0.0
# F1 2017.07.16 experiment control, nm, 120.0, 56.768
# F1 2017.07.16 experiment control, nf, 20.892, 10.081
# F2 2017.05.25 experiment treatment, m, 120.848, 0.8479999999999999
# F2 2017.05.25 experiment treatment, f, 120.848, 0.8479999999999999
# F2 2017.05.25 experiment treatment, nm, 67.41, 99.651
# F2 2017.05.25 experiment treatment, nf, 67.56, 79.587
# F2 2017.05.09 experiment control, m, 83.766, 9.08
# F2 2017.05.09 experiment control, f, 84.359, 56.726
# F2 2017.05.09 experiment control, nm, 124.734, 11.16
# F2 2017.05.09 experiment control, nf, 36.014, 4.734
# F5 2017.05.01 experiment control, m, 120.386, 0.38599999999999923
# F5 2017.05.01 experiment control, f, 120.386, 0.38599999999999923
# F5 2017.05.01 experiment control, nm, 120.386, 9.600999999999999
# F5 2017.05.01 experiment control, nf, 120.386, 120.386
# F2 2017.07.08 habituation treatment, m, 139.435, 19.435
# F2 2017.07.08 habituation treatment, f, 139.435, 22.843999999999998
# F2 2017.07.08 habituation treatment, nm, 139.435, 22.843999999999998
# F2 2017.07.08 habituation treatment, nf, 139.435, 32.954
# F1 2017.05.18 experiment control, m, 120.463, 0.4630000000000001
# F1 2017.05.18 experiment control, f, 29.223, 0.4630000000000001
# F1 2017.05.18 experiment control, nm, 120.463, 0.4630000000000001
# F1 2017.05.18 experiment control, nf, 120.463, 0.4630000000000001
# F2 2017.06.11 experiment treatment, m, 120.0, 0.0
# F2 2017.06.11 experiment treatment, f, 120.0, 0.0
# F2 2017.06.11 experiment treatment, nm, 120.0, 0.6900000000000004
# F2 2017.06.11 experiment treatment, nf, 120.0, 0.0
# F6 2017.05.07 habituation treatment, m, 126.071, 6.071000000000001
# F6 2017.05.07 habituation treatment, f, 126.071, 48.458
# F6 2017.05.07 habituation treatment, nm, 126.071, 126.071
# F6 2017.05.07 habituation treatment, nf, 126.071, 122.35900000000001
# F5 2017.06.03 experiment treatment, m, 120.386, 0.3860000000000001
# F5 2017.06.03 experiment treatment, f, 120.386, 0.3860000000000001
# F5 2017.06.03 experiment treatment, nm, 120.386, 0.3860000000000001
# F5 2017.06.03 experiment treatment, nf, 120.386, 0.3860000000000001
# F1 2017.06.17 habituation control, m, 125.372, 27.878999999999998
# F1 2017.06.17 habituation control, f, 125.372, 45.331
# F1 2017.06.17 habituation control, nm, 125.372, 5.372
# F1 2017.06.17 habituation control, nf, 125.372, 12.68
# F1 2017.06.09 habituation treatment, m, 129.183, 19.871
# F1 2017.06.09 habituation treatment, f, 129.183, 19.871
# F1 2017.06.09 habituation treatment, nm, 9.183, 23.45
# F1 2017.06.09 habituation treatment, nf, 129.183, 129.183
# F6 2017.07.16 experiment treatment, m, 120.0, 9.432
# F6 2017.07.16 experiment treatment, f, 69.84899999999999, 58.175000000000004
# F6 2017.07.16 experiment treatment, nm, 120.0, 0.0
# F6 2017.07.16 experiment treatment, nf, 120.0, 0.0
# F2 2017.06.18 experiment control, m, 120.0, 0.0
# F2 2017.06.18 experiment control, f, 89.708, 94.349
# F2 2017.06.18 experiment control, nm, 120.0, 0.0
# F2 2017.06.18 experiment control, nf, 120.0, 0.0
# F6 2017.06.17 habituation treatment, m, 121.242, 1.242
# F6 2017.06.17 habituation treatment, f, 121.242, 3.1470000000000002
# F6 2017.06.17 habituation treatment, nm, 121.242, 2.746
# F6 2017.06.17 habituation treatment, nf, 121.242, 14.206
# F6 2017.05.01 experiment control, m, 120.011, 0.010999999999999233
# F6 2017.05.01 experiment control, f, 106.24900000000001, 0.010999999999999233
# F6 2017.05.01 experiment control, nm, 120.011, 0.010999999999999233
# F6 2017.05.01 experiment control, nf, 24.776, 0.010999999999999233
# F5 2017.06.17 habituation treatment, m, 74.913, 44.845
# F5 2017.06.17 habituation treatment, f, 115.886, 44.272
# F5 2017.06.17 habituation treatment, nm, 146.163, 46.016
# F5 2017.06.17 habituation treatment, nf, 104.082, 26.163
# F5 2017.05.31 habituation treatment, m, 26.198, 22.273
# F5 2017.05.31 habituation treatment, f, 120.001, 25.016
# F5 2017.05.31 habituation treatment, nm, 120.001, 0.001
# F5 2017.05.31 habituation treatment, nf, 23.392, 3.6910000000000003
# F5 2017.05.09 experiment treatment, m, 120.0, 0.0
# F5 2017.05.09 experiment treatment, f, 120.0, 0.0
# F5 2017.05.09 experiment treatment, nm, 120.0, 0.0
# F5 2017.05.09 experiment treatment, nf, 10.887, 0.0
# F1 2017.05.16 habituation control, m, 154.863, 34.863
# F1 2017.05.16 habituation control, f, 154.863, 128.299
# F1 2017.05.16 habituation control, nm, 154.863, 69.143
# F1 2017.05.16 habituation control, nf, 154.863, 154.863
# F6 2017.07.09 experiment control, m, 120.003, 0.003
# F6 2017.07.09 experiment control, f, 120.003, 0.003
# F6 2017.07.09 experiment control, nm, 120.003, 0.003
# F6 2017.07.09 experiment control, nf, 120.003, 0.003
# F1 2017.05.31 habituation control, m, 173.362, 53.362
# F1 2017.05.31 habituation control, f, 173.362, 53.362
# F1 2017.05.31 habituation control, nm, 173.362, 54.153
# F1 2017.05.31 habituation control, nf, 173.362, 54.153
# F5 2017.06.24 habituation control, m, 124.59, 4.59
# F5 2017.06.24 habituation control, f, 124.59, 22.013
# F5 2017.06.24 habituation control, nm, 99.757, 22.013
# F5 2017.06.24 habituation control, nf, 124.59, 41.531
# F6 2017.06.11 experiment control, m, 20.506, 0.0
# F6 2017.06.11 experiment control, f, 22.049, 0.0
# F6 2017.06.11 experiment control, nm, 120.0, 0.0
# F6 2017.06.11 experiment control, nf, 120.0, 0.0
# F6 2017.06.09 habituation control, m, 145.527, 34.657
# F6 2017.06.09 habituation control, f, 25.527, 31.79
# F6 2017.06.09 habituation control, nm, 145.527, 50.69
# F6 2017.06.09 habituation control, nf, 145.527, 145.527
# F6 2017.04.18 habituation control, m, 124.184, 23.625
# F6 2017.04.18 habituation control, f, 124.184, 4.184
# F6 2017.04.18 habituation control, nm, 124.184, 86.65100000000001
# F6 2017.04.18 habituation control, nf, 124.184, 21.933000000000003
# F2 2017.06.17 habituation control, m, 123.243, 4.69
# F2 2017.06.17 habituation control, f, 123.243, 3.243
# F2 2017.06.17 habituation control, nm, 123.243, 13.348
# F2 2017.06.17 habituation control, nf, 123.243, 35.499
# F6 2017.06.24 habituation control, m, 138.715, 55.034
# F6 2017.06.24 habituation control, f, 138.715, 114.8
# F6 2017.06.24 habituation control, nm, 52.27, 68.317
# F6 2017.06.24 habituation control, nf, 138.715, 18.715
# F1 2017.05.25 experiment treatment, m, 120.292, 31.700000000000003
# F1 2017.05.25 experiment treatment, f, 120.292, 31.700000000000003
# F1 2017.05.25 experiment treatment, nm, 120.292, 0.2919999999999998
# F1 2017.05.25 experiment treatment, nf, 120.292, 0.2919999999999998
# F1 2017.06.24 habituation treatment, m, 151.92000000000002, 151.92000000000002
# F1 2017.06.24 habituation treatment, f, 151.92000000000002, 142.887
# F1 2017.06.24 habituation treatment, nm, 61.512, 58.489
# F1 2017.06.24 habituation treatment, nf, 60.667, 31.92
# F5 2017.05.18 experiment treatment, m, 120.011, 13.097999999999999
# F5 2017.05.18 experiment treatment, f, 120.011, 0.01100000000000012
# F5 2017.05.18 experiment treatment, nm, 26.541999999999998, 0.01100000000000012
# F5 2017.05.18 experiment treatment, nf, 27.738, 0.01100000000000012
# F6 2017.07.08 habituation control, m, 226.78199999999998, 106.782
# F6 2017.07.08 habituation control, f, 226.78199999999998, 226.78199999999998
# F6 2017.07.08 habituation control, nm, 226.78199999999998, 226.78199999999998
# F6 2017.07.08 habituation control, nf, 226.78199999999998, 226.78199999999998
# F2 2017.05.07 habituation control, m, 43.132, 27.182000000000002
# F2 2017.05.07 habituation control, f, 131.017, 27.182000000000002
# F2 2017.05.07 habituation control, nm, 131.017, 110.727
# F2 2017.05.07 habituation control, nf, 131.017, 11.017
# F1 2017.05.24 habituation treatment, m, 88.343, 162.899
# F1 2017.05.24 habituation treatment, f, 88.568, 83.428
# F1 2017.05.24 habituation treatment, nm, 86.555, 44.94
# F1 2017.05.24 habituation treatment, nf, 162.899, 42.899
# F5 2017.07.16 experiment treatment, m, 18.238, 0.0
# F5 2017.07.16 experiment treatment, f, 18.238, 0.0
# F5 2017.07.16 experiment treatment, nm, 120.0, 0.0
# F5 2017.07.16 experiment treatment, nf, 70.026, 0.0
# F6 2017.05.25 experiment control, m, 47.87, 0.18800000000000017
# F6 2017.05.25 experiment control, f, 120.188, 0.18800000000000017
# F6 2017.05.25 experiment control, nm, 120.188, 0.18800000000000017
# F6 2017.05.25 experiment control, nf, 64.609, 0.18800000000000017
# F1 2017.05.07 habituation control, m, 121.513, 117.124
# F1 2017.05.07 habituation control, f, 121.513, 115.815
# F1 2017.05.07 habituation control, nm, 121.513, 1.5129999999999997
# F1 2017.05.07 habituation control, nf, 121.513, 66.326
# F6 2017.05.24 habituation control, m, 154.306, 60.981
# F6 2017.05.24 habituation control, f, 154.306, 34.306000000000004
# F6 2017.05.24 habituation control, nm, 154.306, 154.306
# F6 2017.05.24 habituation control, nf, 85.954, 154.306
# F5 2017.05.24 habituation control, m, 53.47, 4.098000000000001
# F5 2017.05.24 habituation control, f, 53.47, 15.799
# F5 2017.05.24 habituation control, nm, 123.47, 5.442
# F5 2017.05.24 habituation control, nf, 123.47, 3.4699999999999998
# F2 2017.04.28 habituation treatment, m, 178.679, 62.699
# F2 2017.04.28 habituation treatment, f, 178.679, 58.679
# F2 2017.04.28 habituation treatment, nm, 178.679, 58.679
# F2 2017.04.28 habituation treatment, nf, 178.679, 60.867
# F2 2017.07.09 experiment treatment, m, 120.003, 0.003
# F2 2017.07.09 experiment treatment, f, 118.11999999999999, 0.003
# F2 2017.07.09 experiment treatment, nm, 120.003, 0.003
# F2 2017.07.09 experiment treatment, nf, 120.003, 0.003
# F2 2017.05.31 habituation control, m, 127.083, 14.144
# F2 2017.05.31 habituation control, f, 104.994, 9.344
# F2 2017.05.31 habituation control, nm, 127.083, 7.083
# F2 2017.05.31 habituation control, nf, 121.29, 11.219
# F2 2017.06.09 habituation treatment, m, 123.29, 11.478
# F2 2017.06.09 habituation treatment, f, 73.987, 34.669
# F2 2017.06.09 habituation treatment, nm, 123.29, 45.488
# F2 2017.06.09 habituation treatment, nf, 123.29, 3.29
# F1 2017.06.18 experiment control, m, 120.138, 0.138
# F1 2017.06.18 experiment control, f, 120.138, 0.138
# F1 2017.06.18 experiment control, nm, 120.138, 0.138
# F1 2017.06.18 experiment control, nf, 120.138, 0.138
# F2 2017.06.23 experiment treatment, m, 120.0, 0.0
# F2 2017.06.23 experiment treatment, f, 120.0, 0.0
# F2 2017.06.23 experiment treatment, nm, 120.0, 0.0
# F2 2017.06.23 experiment treatment, nf, 120.0, 0.0
# F5 2017.05.25 experiment control, m, 57.756, 0.123
# F5 2017.05.25 experiment control, f, 52.129, 0.123
# F5 2017.05.25 experiment control, nm, 87.818, 0.123
# F5 2017.05.25 experiment control, nf, 120.123, 0.123
# F6 2017.04.28 habituation control, m, 139.767, 27.923000000000002
# F6 2017.04.28 habituation control, f, 139.767, 19.767000000000003
# F6 2017.04.28 habituation control, nm, 139.767, 22.253999999999998
# F6 2017.04.28 habituation control, nf, 139.767, 22.253999999999998
# F1 2017.06.03 experiment control, m, 120.316, 0.31599999999999984
# F1 2017.06.03 experiment control, f, 120.316, 12.462
# F1 2017.06.03 experiment control, nm, 120.316, 0.31599999999999984
# F1 2017.06.03 experiment control, nf, 120.316, 0.31599999999999984
# F2 2017.05.01 experiment treatment, m, 120.004, 0.004000000000000448
# F2 2017.05.01 experiment treatment, f, 120.004, 0.004000000000000448
# F2 2017.05.01 experiment treatment, nm, 120.004, 0.004000000000000448
# F2 2017.05.01 experiment treatment, nf, 70.931, 0.004000000000000448
# F5 2017.06.18 experiment treatment, m, 120.0, 0.0
# F5 2017.06.18 experiment treatment, f, 120.0, 0.0
# F5 2017.06.18 experiment treatment, nm, 120.0, 0.0
# F5 2017.06.18 experiment treatment, nf, 117.488, 0.0
# F6 2017.05.16 habituation treatment, m, 30.87, 52.693000000000005
# F6 2017.05.16 habituation treatment, f, 131.19, 25.616
# F6 2017.05.16 habituation treatment, nm, 11.19, 131.19
# F6 2017.05.16 habituation treatment, nf, 131.19, 77.344
# F5 2017.05.16 habituation treatment, m, 121.822, 1.822
# F5 2017.05.16 habituation treatment, f, 121.822, 1.822
# F5 2017.05.16 habituation treatment, nm, 121.822, 34.683
# F5 2017.05.16 habituation treatment, nf, 121.822, 14.994
# F2 2017.06.03 experiment control, m, 120.212, 0.21199999999999974
# F2 2017.06.03 experiment control, f, 120.212, 0.21899999999999942
# F2 2017.06.03 experiment control, nm, 120.212, 22.088
# F2 2017.06.03 experiment control, nf, 78.637, 30.747000000000003
# F5 2017.06.25 experiment control, m, 120.002, 0.0020000000000000018
# F5 2017.06.25 experiment control, f, 120.002, 0.0020000000000000018
# F5 2017.06.25 experiment control, nm, 120.002, 0.0020000000000000018
# F5 2017.06.25 experiment control, nf, 79.618, 0.0020000000000000018

# %% [markdown]
# This is the core of what we did in the first python script, so first up define a data structure to hold the data.  We already have the `CombiningData`, so that is the "key", and the output will have one row for each `CombiningData`.  The value type is the `BehaviourModifier`.

# %%
# this can't be a namedTuple, as we need to update the fields using set & get attr.
# Use slots for speed & to ensure that only the fields we want are valid.
class BehaviourModifier:
    def __init__(self):
        self.app_neighbour = 0
        self.app_partner = 0
        self.fspr_neighbour = 0
        self.fspr_partner = 0
        self.cavity_neighbour = 0
        self.ST_neighbour = 0
        self.hd_neighbour = 0
        self.hd_partner = 0
        self.bars_neighbour = 0
        self.bars_partner = 0
        self.freeze_neighbour = 0
        self.sbend_neighbour = 0
        self.sbend_partner = 0
        self.l_partner = None
        self.l_neighbour = None
    
    def get_csv(self):
        return ', '.join(['{}'.format(getattr(self, field)) for field in vars(self)])
    
    def get_csv_fields(self):
        return ', '.join(['{}'.format(field) for field in vars(self)])

# %%
def create_pairid_status_lookup_table():
    table = dict()
    return table

# %% [markdown]
# Iterate over the observations, then over the events, and total up how many events of each type are present.

# %%
# key is a CombiningData, value is BehaviourModifier
combo_dict = dict()

for label in observations.keys():
    for subject in ['male_A', 'female_A', 'male_B', 'female_B']:
        combo_dict[CombiningData(label, subject)] = BehaviourModifier()

# iterate over the observations
for label, events in observations.items():

    freeze_state = dict()
    
    # iterate over the events in the observation
    for event in events:
        if not event.subject or event.type == 'vstart':
            if event.type != 'vstart':
                print(f'Missing subject: "{combo.obs_id}" {event}, skipping...')
            continue

        combo = CombiningData(label, event.subject)
        data = combo_dict[combo]
        field = f'{event.type}_{event.recipient}'

        # freeze events are NOT "point" events; they are "state" events, toggling on and off.
        if event.type == 'freeze':
            try:
                # if this fails then it is entering the freeze state
                start_time = freeze_state[event.subject]
                # leaving freeze state, remove from dict
                del freeze_state[event.subject]
                setattr(data, field, getattr(data, field) + (event.timestamp - start_time))
            
            except KeyError:
                freeze_state[event.subject] = event.timestamp
            # Skip normal increment stuff here
            continue
        
        # now increment certain fields
        try:
            setattr(data, field, getattr(data, field) + 1)

        except AttributeError:
            # pre-agg should just be ignored in the analysis
            assert field == 'pre-agg_', field

            # ignore errors
            continue

        combo_dict[combo] = data
# Out:
# Missing subject: "F5 2017.04.21 experiment control" "192.15099999999998, , app, neighbour", skipping...
# Missing subject: "F5 2017.04.21 experiment control" "270.591, , app, neighbour", skipping...
# Missing subject: "F5 2017.07.09 experiment control" "137.646, , fspr, neighbour", skipping...
# Missing subject: "F5 2017.05.01 experiment control" "439.122, , ST, neighbour", skipping...
# Missing subject: "F6 2017.05.01 experiment control" "294.902, , app, partner", skipping...
# Missing subject: "F5 2017.05.18 experiment treatment" "564.285, , fspr, neighbour", skipping...
# Missing subject: "F5 2017.05.18 experiment treatment" "589.7479999999999, , fspr, neighbour", skipping...
# Missing subject: "F2 2017.06.09 habituation treatment" "495.343, , app, partner", skipping...
# Missing subject: "F6 2017.04.28 habituation control" "106.33099999999999, , app, neighbour", skipping...

# %% [markdown]
# Inserting the latencies can be done in one place.  As both the `combo_dict` and `latencies` use the same set of keys, the lookup should never fail.

# %%
for combo_label, item in combo_dict.items():
    item.l_partner = latencies[combo_label].partner
    item.l_neighbour = latencies[combo_label].neighbour

# %% [markdown]
# Sanity check: there should be $4 \times len(observations)$ in combo data, as each observation has four subjects.

# %%
print(f'Combo dict has {len(combo_dict)} items, should have {4 * len(observations)} items')
assert len(combo_dict) == 4 * len(observations)
# Out:
# Combo dict has 316 items, should have 316 items

# %% [markdown]
# Finally output the data to a csv file.

# %%
# now output the data to a csv file for further processing
with open('output_data_long_videos.csv','w') as f:
    f.write(f'tank_num, date, phase, cond, subject, {BehaviourModifier().get_csv_fields()}\n')
    for k, v in combo_dict.items():
        f.write(f'{k.get_csv()}, {v.get_csv()}\n')

    print(f'Wrote {f.tell()} bytes')
# Out:
# Wrote 35135 bytes
